# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline

# %%
df = pd.read_csv("data/variables.csv", index_col=False)

# %% [markdown]
# ## mths_since_last_delinq

# %%
df['mths_since_last_delinq'].plot.hist()

# %%
boundary = df['mths_since_last_delinq'].mean() + 3*df['mths_since_last_delinq'].std()
boundary
# Out:
# 100.64329406296963

# %%
df2 = df[df['mths_since_last_delinq'] < boundary]
df.loc[df['mths_since_last_delinq'].isnull(), ['mths_since_last_delinq']] = df2['mths_since_last_delinq'].mean()

# %%
df = df[df['mths_since_last_delinq'] < boundary]
df['mths_since_last_delinq'].plot.hist()

# %% [markdown]
# ## mths_since_last_record

# %%
df['mths_since_last_record'].plot.hist()

# %%
print(len(df))
print(df['mths_since_last_record'].isna().sum())
# Out:
# 256900
# 224236

# %%
df.drop(columns='mths_since_last_record', inplace=True)

# %% [markdown]
# ## open_acc

# %%
df['open_acc'].plot.hist()

# %%
print(len(df))
print(df['open_acc'].isna().sum())
# Out:
# 256900
# 29

# %%
boundary = df['open_acc'].mean() + 3*df['open_acc'].std()
boundary
# Out:
# 25.644016426044825

# %%
df2 = df[df['open_acc'] < boundary]
df.loc[df['open_acc'].isnull(), ['open_acc']] = df2['open_acc'].mean()

# %%
df = df[df['open_acc'] < boundary]
df['open_acc'].plot.hist()

# %% [markdown]
# ## pub_rec

# %%
df['pub_rec'].plot.hist()

# %%
print(len(df))
print(df['pub_rec'].isna().sum())
# Out:
# 254070
# 29

# %%
boundary = df['pub_rec'].mean() + 3*df['pub_rec'].std()
boundary
# Out:
# 1.4513596825165334

# %%
df2 = df[df['pub_rec'] < boundary]
df.loc[df['pub_rec'].isnull(), ['pub_rec']] = df2['pub_rec'].mean()

# %%
df = df[df['pub_rec'] < boundary]
df['pub_rec'].plot.hist()

# %% [markdown]
# ## revol_bal

# %%
df['revol_bal'].plot.hist()

# %%
print(len(df))
print(df['revol_bal'].isna().sum())
# Out:
# 250468
# 0

# %%
boundary = df['revol_bal'].mean() + 3*df['revol_bal'].std()
boundary
# Out:
# 72185.94211115259

# %%
df2 = df[df['revol_bal'] < boundary]
df.loc[df['revol_bal'].isnull(), ['revol_bal']] = df2['revol_bal'].mean()

# %%
df = df[df['revol_bal'] < boundary]
df['revol_bal'].plot.hist()

# %% [markdown]
# ## revol_util

# %%
df['revol_util'].plot.hist()

# %%
print(len(df))
print(df['revol_util'].isna().sum())
# Out:
# 247277
# 232

# %%
boundary = df['revol_util'].mean() + 3*df['revol_util'].std()
boundary
# Out:
# 128.9104606028891

# %%
df2 = df[df['revol_util'] < boundary]
df.loc[df['revol_util'].isnull(), ['revol_util']] = df2['revol_util'].mean()

# %%
df = df[df['revol_util'] < boundary]
df['revol_util'].plot.hist()

# %% [markdown]
# ## total_acc

# %%
df['total_acc'].plot.hist()

# %%
print(len(df))
print(df['total_acc'].isna().sum())
# Out:
# 247272
# 29

# %%
boundary = df['total_acc'].mean() + 3*df['total_acc'].std()
boundary
# Out:
# 58.80944783685386

# %%
df2 = df[df['total_acc'] < boundary]
df.loc[df['total_acc'].isnull(), ['total_acc']] = df2['total_acc'].mean()

# %%
df = df[df['total_acc'] < boundary]
df['total_acc'].plot.hist()

# %% [markdown]
# ## collections_12_mths_ex_med

# %%
df['collections_12_mths_ex_med'].plot.hist()

# %%
print(len(df))
print(df['collections_12_mths_ex_med'].isna().sum())
# Out:
# 245181
# 138

# %%
df.drop(columns='collections_12_mths_ex_med', inplace=True)

# %% [markdown]
# ## mths_since_last_major_derog - ?

# %%
df['mths_since_last_major_derog'].plot.hist()

# %%
print(len(df))
print(df['mths_since_last_major_derog'].isna().sum())
# Out:
# 245181
# 200230

# %%
boundary = df['mths_since_last_major_derog'].mean() + 3*df['mths_since_last_major_derog'].std()
boundary
# Out:
# 107.64775348637575

# %%
df2 = df[df['mths_since_last_major_derog'] < boundary]
df.loc[df['mths_since_last_major_derog'].isnull(), ['mths_since_last_major_derog']] = df2['mths_since_last_major_derog'].mean()

# %%
df = df[df['mths_since_last_major_derog'] < boundary]
df['mths_since_last_major_derog'].plot.hist()

# %% [markdown]
# ## annual_inc_joint

# %%
df['annual_inc_joint'].plot.hist()

# %%
print(len(df))
print(df['annual_inc_joint'].isna().sum())
# Out:
# 245032
# 245031

# %%
df.drop(columns='annual_inc_joint', inplace=True)

# %% [markdown]
# ## dti_joint

# %%
df['dti_joint'].plot.hist()

# %%
print(len(df))
print(df['dti_joint'].isna().sum())
# Out:
# 245032
# 245031

# %%
df.drop(columns='dti_joint', inplace=True)

# %% [markdown]
# ## acc_now_delinq

# %%
df['acc_now_delinq'].plot.hist()

# %%
print(len(df))
print(df['acc_now_delinq'].isna().sum())
# Out:
# 245032
# 29

# %%
df.drop(columns='acc_now_delinq', inplace=True)

# %% [markdown]
# ## tot_coll_amt

# %%
df['tot_coll_amt'].plot.hist()

# %%
print(len(df))
print(df['tot_coll_amt'].isna().sum())
# Out:
# 245032
# 64733

# %%
df.drop(columns='tot_coll_amt', inplace=True)

# %%
df.drop(columns='Unnamed: 0', inplace=True)

new_df = df[['id', 'mths_since_last_delinq', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'mths_since_last_major_derog']]

new_df.head()
# Out:
#         id  mths_since_last_delinq  open_acc  pub_rec  revol_bal  revol_util  \
# 0  1077501               35.030607       3.0      0.0    13648.0        83.7
# 1  1077430               35.030607       3.0      0.0     1687.0         9.4
# 2  1077175               35.030607       2.0      0.0     2956.0        98.5
# 3  1076863               35.000000      10.0      0.0     5598.0        21.0
# 4  1075269               35.030607       9.0      0.0     7963.0        28.3
#
#    total_acc  mths_since_last_major_derog
# 0        9.0                    42.869693
# 1        4.0                    42.869693
# 2       10.0                    42.869693
# 3       37.0                    42.869693
# 4       12.0                    42.869693

# %%
new_df.to_csv('data/pedro_scalar.csv', index=False)
